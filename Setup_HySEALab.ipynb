# %% [markdown]
# # 🚀 Setup Rápido de Epsilon para HySEALab
#
# ## ⚠️ IMPORTANTE: Ejecuta este notebook UNA SOLA VEZ para configurar tu entorno
#
# Este notebook va a:
# 1. ✅ Crear la estructura de directorios en tu home (~/ proyecto_tsunami/)
# 2. ✅ Copiar el manual a tu carpeta personal
# 3. ✅ Crear tu archivo de configuración personalizado
#
# Después de ejecutarlo, cierra este notebook y trabaja desde `~/proyecto_tsunami/Manual_Usuario_Epsilon.ipynb`

# %% [markdown]
# ---
# ## Paso 1: Ejecutar el setup
#
# Ejecuta la siguiente celda para configurar tu entorno automáticamente:

# %%
# Setup automático de Epsilon para HySEALab
import sys
from pathlib import Path

# Importar el script de setup
setup_script = Path.home() / "HySEALab" / "HySEALab-Library" / "setup_hysealab.py"

if setup_script.exists():
    # Ejecutar el script
    # %run {setup_script}
else:
    print("❌ No se encontró el script de setup")
    print(f"   Buscado en: {setup_script}")
    print("\n   Verifica que estés en el entorno HySEALab y que el repositorio esté actualizado")

# %% [markdown]
# ---
# ## Paso 2: Configurar tus rutas (OPCIONAL)
#
# Si quieres personalizar las rutas antes de empezar, edita el archivo de configuración:

# %%
# Ver el contenido del archivo de configuración
from pathlib import Path

config_file = Path.home() / "proyecto_tsunami" / "epsilon_config.py"

if config_file.exists():
    print(f"📝 Archivo de configuración: {config_file}")
    print("\nContenido actual (primeras 30 líneas):\n")
    print("=" * 60)
    with open(config_file, 'r') as f:
        lines = f.readlines()[:30]
        print(''.join(lines))
    print("=" * 60)
    print("\n💡 Para editarlo: Abre este archivo en el explorador de JupyterLab")
else:
    print("⚠️  No se encontró el archivo de configuración")

# %% [markdown]
# ---
# ## Paso 3: Verificar la instalación

# %%
# Verificar que todo está correctamente configurado
from pathlib import Path

proyecto_dir = Path.home() / "proyecto_tsunami"
manual_file = proyecto_dir / "Manual_Usuario_Epsilon.ipynb"
config_file = proyecto_dir / "epsilon_config.py"

print("🔍 Verificando instalación...\n")
print("=" * 60)

checks = [
    (proyecto_dir, "Directorio proyecto_tsunami"),
    (manual_file, "Manual de Usuario"),
    (config_file, "Archivo de configuración"),
    (proyecto_dir / "resultados" / "plots", "Carpeta de plots"),
    (proyecto_dir / "mis_notebooks", "Carpeta de notebooks"),
]

all_ok = True
for path, description in checks:
    if path.exists():
        print(f"✅ {description}: {path}")
    else:
        print(f"❌ {description}: NO ENCONTRADO")
        all_ok = False

print("=" * 60)

if all_ok:
    print("\n🎉 ¡Todo listo!")
    print("\n📖 SIGUIENTE PASO:")
    print(f"   1. Cierra este notebook")
    print(f"   2. Navega a: {proyecto_dir}")
    print(f"   3. Abre: Manual_Usuario_Epsilon.ipynb")
    print(f"   4. ¡Empieza a trabajar!")
else:
    print("\n⚠️  Algunos archivos no se encontraron")
    print("   Ejecuta de nuevo el Paso 1")

# %% [markdown]
# ---
# ## 📚 Documentación Adicional
#
# - **Manual completo**: `~/proyecto_tsunami/Manual_Usuario_Epsilon.ipynb`
# - **Guía de setup**: `~/HySEALab/HySEALab-Library/SETUP_USUARIO.md`
# - **README**: `~/HySEALab/HySEALab-Library/README.md`
#
# ---
#
# ## ⚠️ Recuerda:
#
# - ❌ **NO ejecutes notebooks desde** `~/HySEALab/HySEALab-Library`
# - ✅ **Trabaja siempre desde** `~/proyecto_tsunami/`
# - ✅ La biblioteca epsilon.py se importa automáticamente desde la carpeta compartida
